# %%
from Code.GAN.GAN import evalGan as Evaluate
import logging
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # FATAL
logging.getLogger('tensorflow').setLevel(logging.FATAL) # Silence tensorflow logging messages

# %%
Evaluate(discEpoch=28, genEpoch=28)
# Out:
# 372/372 [==============================] - 31s 78ms/step - loss: 1.0367 - F1: 0.3341 - accuracy: 0.9325 - precision: 0.5062 - recall: 0.2494 - true_positives: 51460.0000 - true_negatives: 2785292.0000 - false_positives: 50200.0000 - false_negatives: 154848.0000
# ({'loss': 1.0367069244384766,
#   'F1': array([0.33412218], dtype=float32),
#   'accuracy': 0.9325228333473206,
#   'precision': 0.5061971545219421,
#   'recall': 0.24943289160728455,
#   'true_positives': 51460.0,
#   'true_negatives': 2785292.0,
#   'false_positives': 50200.0,
#   'false_negatives': 154848.0},
#  [array([[[ 0.51270771, -0.51054487,  0.61402971, ...,  0.        ,
#            -0.08931841,  0.        ],
#           [ 0.52963404, -0.51022766,  0.61402971, ...,  0.        ,
#            -0.08931841,  0.        ],
#           [ 0.56743532, -0.51054487,  0.61402971, ...,  0.        ,
#            -0.08931841,  0.        ],
#           [ 0.60721134, -0.50959404,  0.61402971, ...,  0.        ,
# ...
